# %%
# !pip install ydata-profiling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.3/399.3 kB 15.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 22.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 76.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 42.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 42.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.3
#     Uninstalling scipy-1.16.3:
#       Successfully uninstalled scipy-1.16.3
# ...

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# Cargar el archivo CSV
df = pd.read_csv('Accidentalidad_Municipio_de__Envigado_20251028.csv')

# Ver las primeras filas para confirmar que cargó bien
df.head()
# Out:
# /tmp/ipython-input-1550930855.py:5: DtypeWarning: Columns (4,5,6,7,13,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Accidentalidad_Municipio_de__Envigado_20251028.csv')
#    RADICADO      FECHA            HORA DÍA DE LA SEMANA CLASE DE VEHICULO  \
# 0   2134024  1/01/2014  10:30:00 p. m.        Miércoles               NaN
# 1   2134024  1/01/2014  10:30:00 p. m.        Miércoles               NaN
# 2   2134026  1/01/2014  11:30:00 p. m.        Miércoles               NaN
# 3   2134026  1/01/2014  11:30:00 p. m.        Miércoles               NaN
# 4   2134026  1/01/2014  11:30:00 p. m.        Miércoles               NaN
#
#   TIPO DE SERVICIO TIPO DE VICTIMA SEXO  ESTADO DE BEODEZ  \
# 0              NaN             NaN  NaN                 0
# 1              NaN             NaN  NaN                 0
# 2              NaN             NaN  NaN                 0
# 3              NaN             NaN  NaN                 0
# ...

# %%
# Crear el reporte de perfilado
profile = ProfileReport(df, title="Reporte Exploratorio - Mi Dataset", explorative=True)

# Mostrar el reporte en el notebook
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling vv4.17.0&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2025-11-09 20:52:18.835506&quot; name=date&gt;&lt;title&gt;Reporte Exploratorio - Mi Dataset&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
# !ls
# Out:
# Accidentalidad_Municipio_de__Envigado_20251028.csv  sample_data
